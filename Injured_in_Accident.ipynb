# %% [markdown]
# ### Comprehensive Analysis of Road Accidents and Injuries in Indian States/Union Territories on State Highways in 2018 - 2021

# %% [markdown]
# #### DATA :- INDIAN  STATE  HIGHWAY
# #### Source of data :- data.gov.in  ( Authorised indian government publised data on 25-09-2023)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
idf=pd.read_csv(r"C:\Users\abdul\Downloads\ROAD ACC\YEAR-18,19,20,21\INJURED.csv")

# %%
idf.shape
# Out:
# (38, 5)

# %%
idf.head()
# Out:
#           States/UTs  \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2              Assam
# 3              Bihar
# 4       Chhattisgarh
#
#    Total Number of Persons Injured in Road Accidents on State Highways during 2018  \
# 0                                             6084.0
# 1                                              109.0
# 2                                             2010.0
# 3                                             1453.0
# 4                                             2866.0
#
#    Total Number of Persons Injured in Road Accidents on State Highways during 2019  \
# 0                                             5949.0
# 1                                              117.0
# 2                                             1869.0
# 3                                             1628.0
# 4                                             2906.0
#
#    Total Number of Persons Injured in Road Accidents on State Highways during 2020  \
# ...

# %%
idf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 5 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   States/UTs                                                                       38 non-null     object
#  1   Total Number of Persons Injured in Road Accidents on State Highways during 2018  37 non-null     float64
#  2   Total Number of Persons Injured in Road Accidents on State Highways during 2019  37 non-null     float64
#  3   Total Number of Persons Injured in Road Accidents on State Highways during 2020  36 non-null     float64
#  4   Total Number of Persons Injured in Road Accidents on State Highways during 2021  37 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.6+ KB

# %%
idf.drop(37,inplace=True)
idf.head()
# Out:
#           States/UTs  \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2              Assam
# 3              Bihar
# 4       Chhattisgarh
#
#    Total Number of Persons Injured in Road Accidents on State Highways during 2018  \
# 0                                             6084.0
# 1                                              109.0
# 2                                             2010.0
# 3                                             1453.0
# 4                                             2866.0
#
#    Total Number of Persons Injured in Road Accidents on State Highways during 2019  \
# 0                                             5949.0
# 1                                              117.0
# 2                                             1869.0
# 3                                             1628.0
# 4                                             2906.0
#
#    Total Number of Persons Injured in Road Accidents on State Highways during 2020  \
# ...

# %%
idf.fillna(value=0,inplace=True)
idf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   States/UTs                                                                       37 non-null     object
#  1   Total Number of Persons Injured in Road Accidents on State Highways during 2018  37 non-null     float64
#  2   Total Number of Persons Injured in Road Accidents on State Highways during 2019  37 non-null     float64
#  3   Total Number of Persons Injured in Road Accidents on State Highways during 2020  37 non-null     float64
#  4   Total Number of Persons Injured in Road Accidents on State Highways during 2021  37 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.6+ KB

# %%
idf.columns=["states","i2018","i2019","i2020","i2021"]

# %% [markdown]
# ### What were the top five Indian states & UTs with the highest number of injured individuals in state highway accidents in 2018?

# %%
#  YEAR 2018
plt.figure(figsize=(13,8))
df=idf.sort_values(by="i2018",ascending=False).head(20)
bp=sns.barplot(y="states",x="i2018",data=df)
for bars in bp.containers:
    bp.bar_label(bars)
bp.set(ylabel="States",xlabel=" Injured in Accident",title="Accidents in Year 2018")
plt.xticks(rotation=70)
plt.grid(axis="x",alpha=0.5)
plt.show()

# %% [markdown]
# #### What were the top five Indian states & UTs with the highest number of injured individuals in state highway accidents in 2018?
#
#  In 2018, the top five Indian states with the highest number of injured individuals in state highway accidents were as follows:
#
# 1. Tamil Nadu (TN) - 26,739 injuries
# 2. Madhya Pradesh (MP) - 15,692 injuries
# 3. Karnataka - 14,544 injuries
# 4. Uttar Pradesh (UP) - 9,545 injuries
# 5. Kerala - 8,756 injuries.

# %% [markdown]
# ### What were the top five Indian states & UTs with the highest number of injured individuals in state highway accidents in 2019?

# %%
# YEAR 2019
plt.figure(figsize=(13,8))
df=idf.sort_values(by="i2019",ascending=False).head(20)
bp=sns.barplot(y="states",x="i2019",data=df)
for bars in bp.containers:
    bp.bar_label(bars)
bp.set(ylabel="States",xlabel="Injured in Accident",title="Accidents in Year 2019")
plt.xticks(rotation=70)
plt.grid(axis="x",alpha=0.5)
plt.show()

# %% [markdown]
# #### What were the top five Indian states with the highest number of injured individuals in state highway accidents in 2019?
#
# In 2019, the top five Indian states with the highest number of injured individuals in state highway accidents were as follows:
#
# 1. Tamil Nadu (TN) - 22,477 injuries
# 2. Madhya Pradesh (MP) - 14,169 injuries
# 3. Karnataka - 13,626 injuries
# 4. Kerala - 9,335 injuries
# 5. Uttar Pradesh (UP) - 9,272 injuries.

# %% [markdown]
# ### What were the top five Indian states & UTs with the highest number of injured individuals in state highway accidents in 2020?

# %%
# YEAR 2020
plt.figure(figsize=(13,8))
df=idf.sort_values(by="i2020",ascending=False).head(20)
bp=sns.barplot(y="states",x="i2020",data=df)
for bars in bp.containers:
    bp.bar_label(bars)
bp.set(ylabel="States",xlabel="Injured in Accident",title="Accidents in Year 2020")
plt.xticks(rotation=70)
plt.grid(axis="x",alpha=0.5)
plt.show()

# %% [markdown]
# #### What were the top five Indian states with the highest number of injured individuals in state highway accidents in 2020?
# In 2020, the top five Indian states with the highest number of injured individuals in state highway accidents were as follows:
#
# 1. Tamil Nadu - 18,780 injuries
# 2. Madhya Pradesh - 12,547 injuries
# 3. Karnataka - 11,791 injuries
# 4. Uttar Pradesh - 6,776 injuries
# 5. Kerala - 6,518 injuries.

# %% [markdown]
# ### What were the top five Indian states & UTs with the highest number of injured individuals in state highway accidents in 2021?

# %%
# YEAR 2021
plt.figure(figsize=(13,8))
df=idf.sort_values(by="i2021",ascending=False).head(20)
bp=sns.barplot(y="states",x="i2021",data=df)
for bars in bp.containers:
    bp.bar_label(bars)
bp.set(ylabel="States",xlabel=" Injured in Accident ",title="Accidents in Year 2021")
plt.xticks(rotation=70)
plt.grid(axis="x",alpha=0.5)
plt.show()

# %% [markdown]
# #### What were the top five Indian states with the highest number of injured individuals in state highway accidents in 2021?
#  In 2021, the top five Indian states with the highest number of injured individuals in state highway accidents were as follows:
#
# 1. Tamil Nadu - 18,409 injuries
# 2. Madhya Pradesh - 12,052 injuries
# 3. Karnataka - 11,507 injuries
# 4. Kerala - 8,161 injuries
# 5. Uttar Pradesh - 7,155 injuries.

# %% [markdown]
# #### Tamil Nadu consistently appears as one of the states with the highest number of injured individuals in state highway accidents in all four years (2018, 2019, 2020, and 2021).
# ###
# #### While Tamil Nadu is consistently at the top, the rankings of other states change over the years. For example, Madhya Pradesh, Karnataka, Kerala, and Uttar Pradesh show variations in their rankings from year to year.

# %% [markdown]
# ## An Comparative Analysis of Data Trends: 2018 vs. 2021

# %%
plt.figure(figsize=(19,5))
categories1 = idf.sort_values(by="i2018",ascending=False)["states"].head(15).tail(14)
values1 = idf.sort_values(by="i2018",ascending=False)["i2018"].head(15).tail(14)
values4 = idf.sort_values(by="i2021",ascending=False)["i2021"].head(15).tail(14)
bar_width = 0.20
x1 = np.arange(len(categories1))
x2 = [x + bar_width for x in x1]
plt.bar(x1, values1, width=bar_width, label='2018',color="r",alpha=0.6)
plt.bar(x2, values4, width=bar_width, label='2021',color="g",alpha=0.6)
plt.xticks(x1 + bar_width / 1, categories1 , rotation=45)
plt.text(x=2,y=12000,s="Data suggests a decrease in injuries on state highways in 2021 compared to 2018 in most States & UTs",fontsize=15)
plt.title("Comparision between year 2018 & 2021",fontsize=20)
plt.legend()
plt.grid(axis="y",alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(19,5))
df=idf.sort_values(by="i2018",ascending=False).head(15).tail(14)
sns.lineplot(y="i2018",x="states",data=df,label="2018",color='r',linewidth=2)
sns.lineplot(y="i2021",x="states",data=df,label="2021",color='b',linewidth=2)
plt.fill_between(df["states"],df["i2018"],df["i2021"],color="g",where=df["i2018"]>df["i2021"],alpha=0.5)
plt.title("Comparision between year 2018 & 2021",fontsize=20)
plt.text(x=2,y=12000,s="Data suggests a decrease in injuries on state highways in 2021 compared to 2018 in most States & UTs",fontsize=15)
plt.legend()
plt.xticks(rotation=40)
plt.grid(axis="y",alpha=0.5)
plt.show()

# %%
# Adding Percentage column
idf["percent"]=100-idf["i2021"]/idf["i2018"]*100

# %%
df=idf[["states","percent"]]
df.loc[df['percent'] < -30, 'percent'] = -30
plt.figure(figsize=(19,10))
df1=df.sort_values(by="percent",ascending=False)
bp=sns.barplot(y="states",x="percent",data=df1.dropna())
plt.title("Number of States & UTs in which injuries increased or Decreased (2018 - 2021)",fontsize=20)
plt.text(y=25,x=15,s=">>> Decrease in injuries",fontsize=15,color="g")
plt.text(y=25,x=-25,s="Increase in injuries <<<",fontsize=15,color="r")
plt.grid(axis="x",alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(3,5))
x=df[df["percent"]>=0]["percent"].count()
y=df[df["percent"]<0]["percent"].count()
plt.pie([x,y],colors=["g","r"],labels=["Decrease in Injuries","Increase in Injuries"],autopct="%1.1f%%",pctdistance=0.8)
plt.pie([1],radius=0.55,colors="w")
plt.title("Accident report 2018-2021")
plt.show()

# %%
print(f"There are {x} out of {x+y} States & UTs in which injuries has decreased \nThere are {y}  out of {x+y} States & UTs in which injuries has Increased")
# Out:
# There are 26 out of 33 States & UTs in which injuries has decreased
# There are 7  out of 33 States & UTs in which injuries has Increased

# %% [markdown]
# #### An Comparative Analysis of Data Trends: 2018 vs. 2021
# In our analysis of 36 states and Union Territories (UTs), we found that in the majority of regions (26 out of 33, or 78.8 %), the rate of injuries decreased. These regions include Andaman and Nicobar, Manipur, Sikkim, Haryana, Telangana and etc .
#
#    Conversely, in a minority of regions (7 out of 33, or 21.2 %), the rate of injuries increased. These regions are Dadra and Nagar Haveli, Bihar, Meghalaya and etc.
#
#   Note that data for 5 states and UTs were null during the analysis.

# %% [markdown]
# ## An Comparative Analysis of Data Trends: 2020 vs 2021

# %%
plt.figure(figsize=(19,5))
categories1 = idf.sort_values(by="i2020",ascending=False)["states"].head(15).tail(10)
values1 = idf.sort_values(by="i2020",ascending=False)["i2020"].head(15).tail(10)
values4 = idf.sort_values(by="i2021",ascending=False)["i2021"].head(15).tail(10)
bar_width = 0.20
x1 = np.arange(len(categories1))
x2 = [x + bar_width for x in x1]
plt.bar(x1, values1, width=bar_width, label='2020',color="r",alpha=0.6)
plt.bar(x2, values4, width=bar_width, label='2021',color="g",alpha=0.6)
plt.xticks(x1 + bar_width / 1, categories1 , rotation=45)
plt.text(x=1.5,y=4500,s="Data suggests a increase in injuries on state highways in 2021 compared to 2020 in most States & UTs",fontsize=15)
plt.title("Comparision between year 2018 & 2021",fontsize=20)
plt.legend()
plt.grid(axis="y",alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(20,7))
df=idf.sort_values(by="i2021",ascending=False).head(15).tail(8)
sns.lineplot(y="i2020",x="states",data=df,label="2020",color='r',linewidth=2)
sns.lineplot(y="i2021",x="states",data=df,label="2021",color='b',linewidth=2)
plt.fill_between(df["states"],df["i2020"],df["i2021"],color="r",where=df["i2020"]<df["i2021"],alpha=0.5)
plt.title("Difference between year 2020 & 2021",fontsize=20)
plt.text(x=1,y=3500,s="Increase in injuries on state highways in 2021 compared to 2020 in some states & UTs",fontsize=20)
plt.legend()
plt.xticks(rotation=90)
plt.grid(axis="y",alpha=0.5)
plt.show()

# %%
# Droping Previous Columns
idf.drop(["percent"],axis=1,inplace=True)
# Adding Percentage column
idf["percent"]=100-idf["i2021"]/idf["i2020"]*100

# %%
df=idf[["states","percent"]]
df.loc[df['percent'] < -100, 'percent'] = -100
plt.figure(figsize=(19,10))
df1=df.sort_values(by="percent",ascending=False)
bp=sns.barplot(y="states",x="percent",data=df1.dropna())
plt.title("Number of States & UTs in which injuries increased or Decreased (2020 - 2021)",fontsize=20)
plt.text(y=10,x=5,s=">>>>>Decrease in injuries",fontsize=20,color="g")
plt.text(y=10,x=-50,s="Increase in injuries<<<<<",fontsize=20,color="r")
plt.grid(axis="x",alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(3,5))
x=df[df["percent"]>0]["percent"].count()
y=df[df["percent"]<0]["percent"].count()
plt.pie([x,y],colors=["g","r"],labels=["Decrease in Injuries","Increase in Injuries"],autopct="%1.1f%%",pctdistance=0.8)
plt.pie([1],radius=0.55,colors="w")
plt.title("Accident report 2018-2021")
plt.show()

# %%
print(f"There are {x} out of 31 States & UTs in which injuries has decreased \nThere are {y}  out of 31 States & UTs in which injuries has Increased")
# Out:
# There are 9 out of 31 States & UTs in which injuries has decreased
# There are 24  out of 31 States & UTs in which injuries has Increased

# %% [markdown]
# #### An Comparative Analysis of Data Trends: 2020 vs. 2021
# In our analysis of 36 states and Union Territories (UTs), we found that in the majority of regions (23 out of 31, or 71.9 %), the rate of injuries Increased. These regions include Dadra and Nagar Haveli, Meghalaya, Arunachal Pradesh , Himanchal Pradeshand etc .
#
#    Conversely, in a minority of regions (9 out of 31, or 28.1 %), the rate of injuries Decreased. These regions are Manipur, Jharkhand, Goa, Andaman and Nicobar, Harayana and etc.
#
#   Note that data for 5 states and UTs were null during the analysis.

# %% [markdown]
# #### While the data suggests a decrease in injuries on state highways in 2021 compared to 2018
#    #### (81.2% - Decreased),
# #### it reveals an increase in injuries when compared to the previous year,2020 (71.9% - Increased).

# %% [markdown]
# ### Categorize the data into groups (2018 - 2021)

# %%
idf.loc[idf["i2018"]>idf["i2021"],"Catageroy"]="Decreased"
idf.loc[idf["i2018"]<idf["i2021"],"Catageroy"]="Increased"
idf.loc[(idf["i2018"]>idf["i2019"]) & (idf["i2019"]>idf["i2020"]) & (idf["i2020"]>idf["i2021"]),
"Catageroy"]="Continues_Decrease"
idf.loc[df["percent"].isnull(),"Catageroy"]="No_record"
idf.loc[(idf["i2018"]<idf["i2019"]) & (idf["i2018"]<idf["i2020"]) & (idf["i2020"]<idf["i2021"]),
"Catageroy"]="Continues_Increase"
gidf=idf.groupby("Catageroy")[["states"]]
gidf.count()
# Out:
#                     states
# Catageroy
# Continues_Decrease       9
# Continues_Increase       3
# Decreased               17
# Increased                4
# No_record                4

# %%
gidfx=idf[idf["Catageroy"] != "No_record"]
gidf1=gidfx.groupby("Catageroy",as_index=False)["states"].count()
plt.pie(gidf1["states"],labels=gidf1["Catageroy"],autopct="%1.1f%%",pctdistance=0.8,startangle=40)
plt.pie([1],radius=0.6,colors="w")
plt.title("Percent Catagery")
plt.show()

# %%
gidf=idf.groupby("Catageroy")[["states"]]
print("Gradually Increase")
print(gidf.get_group("Continues_Increase"))
print("\nGradually Decrease")
print(gidf.get_group("Continues_Decrease"))
# Out:
# Gradually Increase
#                     states
# 15               Meghalaya
# 19                  Punjab
# 30  Dadra and Nagar Haveli
#
# Gradually Decrease
#                          states
# 0                Andhra Pradesh
# 5                           Goa
# 7                       Haryana
# 9                     Jharkhand
# 10                    Karnataka
# 12               Madhya Pradesh
# 14                      Manipur
# 22                   Tamil Nadu
# 28  Andaman and Nicobar Islands

# %% [markdown]
# #### An Comparative Analysis of Data Trends: 2018 vs. 2021
# In our analysis of 36 states and Union Territories (UTs), we found that in the majority of regions,
# (9 out of 33, or 27.3%) regions demonstrated a gradual decline in accident injuries. These regions include Andhra Pradesh, Goa, Haryana, Jharkhand, Karnataka, Madhya Pradesh, Manipur, Tamil Nadu, and Andaman and Nicobar Islands.
#
#    Conversely, in a minority of regions  (3 out of 33, or 9.1%) showed a gradual increase in accident injuries. These regions are Meghalaya, Punjab, and Dadra and Nagar Haveli.
#
#   Note that data for 5 states and UTs were null during the analysis.

# %%
# Each year sum of peoples injured in accident
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
y=idf[["i2018","i2019","i2020","i2021"]].sum()
bp=sns.barplot(y=["i2018","i2019","i2020","i2021"],x=y)
for bars in bp.containers:
    bp.bar_label(bars)
plt.title("Yearly Sum of Accidents ", fontsize=20)
plt.xlim(70000,130000)
plt.subplot(1,2,2)
plt.pie(x=y,autopct="%1.1f%%",labels=["i2018","i2019","i2020","i2021"],radius=1.5)
plt.show()

# %% [markdown]
# While the data suggests a increase in injuries on state highways in 2021 compared to 2020 by
# (1.1 %,4375)

# %% [markdown]
# # Final Outcomes

# %% [markdown]
# #### Tamil Nadu consistently appears as one of the states with the highest number of injured individuals in state highway accidents in all four years (2018, 2019, 2020, and 2021).
# ###
# #### While Tamil Nadu is consistently at the top, the rankings of other states change over the years. For example, Madhya Pradesh, Karnataka, Kerala, and Uttar Pradesh show variations in their rankings from year to year.

# %% [markdown]
# While the data suggests a decrease in injuries on state highways in 2021 compared to 2018,
#   it reveals an increase in injuries when compared to the previous year,2020.
#   Increase in injuries on state highways in 2021 compared to 2020 by
# (1.1 %,4375)

# %% [markdown]
# #### An Comparative Analysis of Data Trends: 2018 vs. 2021
# In our analysis of 36 states and Union Territories (UTs), we found that in the majority of regions (26 out of 31, or 81.2 %), the rate of injuries decreased. These regions include Andaman and Nicobar, Manipur, Sikkim, Haryana, Telangana and etc .
#
#    Conversely, in a minority of regions (6 out of 31, or 18.8 %), the rate of injuries increased. These regions are Dadra and Nagar Haveli, Bihar, Meghalaya and etc.
#
#   Note that data for 5 states and UTs were null during the analysis.

# %% [markdown]
# #### An Comparative Analysis of Data Trends: 2018 vs. 2021
# In our analysis of 36 states and Union Territories (UTs), we found that in the majority of regions,
# (9 out of 31, or 28.1%) regions demonstrated a gradual decline in accident injuries. These regions include Andhra Pradesh, Goa, Haryana, Jharkhand, Karnataka, Madhya Pradesh, Manipur, Tamil Nadu, and Andaman and Nicobar Islands.
#
#    Conversely, in a minority of regions  (3 out of 31, or 9.4%) showed a gradual increase in accident injuries. These regions are Meghalaya, Punjab, and Dadra and Nagar Haveli.
#
#   Note that data for 5 states and UTs were null during the analysis.

# %% [markdown]
# # Machine Learning

# %%
sns.pairplot(data=idf)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# removing zeros
idf = idf[(idf != 0).all(axis=1)]

# %%
x=idf[["i2018","i2019","i2020"]]
y=idf["i2021"]
x.head()
# Out:
#     i2018   i2019   i2020
# 0  6084.0  5949.0  4830.0
# 1   109.0   117.0    60.0
# 2  2010.0  1869.0  1416.0
# 3  1453.0  1628.0  1372.0
# 4  2866.0  2906.0  1831.0

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.80,random_state=5)

# %%
model=LinearRegression()

# %%
model.fit(x_train.values,y_train.values)
# Out:
# LinearRegression()

# %%
model.predict([[7028.0,6465.0,4336.0]]) ## MH 2021-5078.0
# Out:
# array([4917.79423366])

# %%
accuracy=model.score(x_test.values,y_test.values)
print(accuracy*100)
# Out:
# 99.25797066509013

# %% [markdown]
# ### Predicting for  Year 2022

# %%
idf["pred_2022"]=model.predict(idf[["i2019","i2020","i2021",]])
idf.head()
# Out:
#               states   i2018   i2019   i2020   i2021    percent  \
# 0     Andhra Pradesh  6084.0  5949.0  4830.0  4786.0   0.910973
# 1  Arunachal Pradesh   109.0   117.0    60.0   106.0 -76.666667
# 2              Assam  2010.0  1869.0  1416.0  1460.0  -3.107345
# 3              Bihar  1453.0  1628.0  1372.0  1927.0 -40.451895
# 4       Chhattisgarh  2866.0  2906.0  1831.0  2056.0 -12.288367
#
#             Catageroy    pred_2022
# 0  Continues_Decrease  4360.231773
# 1           Decreased   101.932624
# 2           Decreased  1294.216988
# 3           Increased  1621.332226
# 4           Decreased  1595.211484

# %%
plt.figure(figsize=(20,8))
x1=idf.sort_values(by="pred_2022",ascending=False)
categories1 = x1["states"].head(15)
values1 = x1["i2021"].head(15)
values4 =x1["pred_2022"].head(15)
bar_width = 0.20
xa = np.arange(len(categories1))
xb = [x + bar_width for x in xa]
plt.bar(xa, values1, width=bar_width, label='2021',color="r",alpha=0.6)
plt.bar(xb, values4, width=bar_width, label='2022',color="g",alpha=0.6)
plt.xticks(xa + bar_width / 1, categories1 , rotation=45)
plt.title("Comparision between year 2021 & 2022 Predicted",fontsize=20)
plt.legend()
plt.grid(axis="y",alpha=0.5)

plt.show()

# %%
plt.figure(figsize=(20,4))
x=[x1[x1["i2021"]>x1["pred_2022"]]["pred_2022"].count(),x1[x1["i2021"]<x1["pred_2022"]]["pred_2022"].count()]
plt.pie(x=x,autopct="%1.1f%%",labels=["Injuries_Decreased","Injuries_Increased"],pctdistance=0.8)
plt.pie([1],radius=0.6,colors="w")
plt.title("Predicting Injures in year 2022")
plt.show()

# %% [markdown]
# In year 2022 Injuries will decrease by 71.9 % (23 states)
# Injuries will increase in 28.1 % (9 States)

# %% [markdown]
# The End...
